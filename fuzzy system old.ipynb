# %% [markdown]
# # Breast Cancer Recurrance Prediction Fuzzy System Implementation
# First we install the scikit fuzzy library

# %%
# %pip install -U scikit-fuzzy
# Out:
# Requirement already satisfied: scikit-fuzzy in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (0.4.2)
# Requirement already satisfied: numpy>=1.6.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from scikit-fuzzy) (1.23.5)
# Requirement already satisfied: scipy>=0.9.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from scikit-fuzzy) (1.10.1)
# Requirement already satisfied: networkx>=1.9.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from scikit-fuzzy) (3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Then we import pandas to manipulate dataframe, numpy to perform array calculations, scikit-fuzzy to implement th fuzzy system and control to determine the fuzzy variables

# %%
import pandas as pd
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %% [markdown]
# Then we load the dataset from the uciml repository

# %%
from ucimlrepo import fetch_ucirepo 
breast_cancer = fetch_ucirepo(id=14)
X = breast_cancer.data.features 
y = breast_cancer.data.targets 
data = X
data['Class'] = y  # Adding the target variable 'Class'
data
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    30-39   premeno      30-34       0-2        no          3   left
# 1    40-49   premeno      20-24       0-2        no          2  right
# 2    40-49   premeno      20-24       0-2        no          2   left
# 3    60-69      ge40      15-19       0-2        no          2  right
# 4    40-49   premeno        0-4       0-2        no          2  right
# ..     ...       ...        ...       ...       ...        ...    ...
# 281  30-39   premeno      30-34       0-2        no          2   left
# 282  30-39   premeno      20-24       0-2        no          3   left
# 283  60-69      ge40      20-24       0-2        no          1  right
# 284  40-49      ge40      30-34     5-Mar        no          3   left
# 285  50-59      ge40      30-34     5-Mar        no          3   left
#
#     breast-quad irradiat                 Class
# 0      left_low       no  no-recurrence-events
# 1      right_up       no  no-recurrence-events
# 2      left_low       no  no-recurrence-events
# 3       left_up       no  no-recurrence-events
# 4     right_low       no  no-recurrence-events
# ..          ...      ...                   ...
# 281     left_up       no     recurrence-events
# 282     left_up      yes     recurrence-events
# 283     left_up       no     recurrence-events
# 284    left_low       no     recurrence-events
# 285    left_low       no     recurrence-events
#
# [286 rows x 10 columns]

# %%
data_clean = data[["age","tumor-size","inv-nodes", "deg-malig", "Class"]]
from datetime import datetime

#Clean the ages by replacing range with average
for index, row in data_clean.iterrows():
    age_list = row["age"].split("-")
    age_average = (float(age_list[0]) + float(age_list[1])) / 2
    # Replace the value in the "age" column with the calculated average
    data_clean.at[index, "age"] = age_average

    tumor_size_list = row["tumor-size"].split("-")
    try:
        tumor_size_list[1] = datetime.strptime(tumor_size_list[1], '%b').month
    except:
        pass
    tumor_size_average = (float(tumor_size_list[0]) + float(tumor_size_list[1])) /2 
    data_clean.at[index, "tumor-size"] = tumor_size_average

    inv_nodes_list = row["inv-nodes"].split("-")
    try:
        inv_nodes_list[1] = datetime.strptime(inv_nodes_list[1], '%b').month
    except:
        pass
    inv_nodes_average = (float(inv_nodes_list[0]) + float(inv_nodes_list[1])) /2 
    data_clean.at[index, "inv-nodes"] = inv_nodes_average
    
    data_clean.at[index, "Class"] = 0 if row["Class"] == "no-recurrence-events" else 1

data_clean["age"] = data_clean["age"].astype(float)
data_clean["tumor-size"] = data_clean["tumor-size"].astype(float)
data_clean["inv-nodes"] = data_clean["inv-nodes"].astype(float)
data_clean["Class"] = data_clean["Class"].astype(float)
data_clean.to_csv('clean-breast-cancer.csv', index=False, header=True)
data_clean
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7320\3838638883.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean["age"] = data_clean["age"].astype(float)
# C:\Users\user\AppData\Local\Temp\ipykernel_7320\3838638883.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean["tumor-size"] = data_clean["tumor-size"].astype(float)
# C:\Users\user\AppData\Local\Temp\ipykernel_7320\3838638883.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean["inv-nodes"] = data_clean["inv-nodes"].astype(float)
# C:\Users\user\AppData\Local\Temp\ipykernel_7320\3838638883.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean["Class"] = data_clean["Class"].astype(float)
#       age  tumor-size  inv-nodes  deg-malig  Class
# 0    34.5        32.0        1.0          3    0.0
# 1    44.5        22.0        1.0          2    0.0
# 2    44.5        22.0        1.0          2    0.0
# 3    64.5        17.0        1.0          2    0.0
# 4    44.5         2.0        1.0          2    0.0
# ..    ...         ...        ...        ...    ...
# 281  34.5        32.0        1.0          2    1.0
# 282  34.5        22.0        1.0          3    1.0
# 283  64.5        22.0        1.0          1    1.0
# 284  44.5        32.0        4.0          3    1.0
# 285  54.5        32.0        4.0          3    1.0
#
# [286 rows x 5 columns]

# %% [markdown]
# Then we define the fuzzy variables:
# *  Placeholder

# %%
# Define fuzzy variables
age = ctrl.Antecedent(np.arange(10, 101, 1), 'age')
tumor_size = ctrl.Antecedent(np.arange(0, 61, 1), 'tumor_size')
inv_nodes = ctrl.Antecedent(np.arange(0, 41, 1), 'inv_nodes')
deg_malig = ctrl.Antecedent(np.arange(1, 4, 1), 'deg_malig')
recurrence = ctrl.Consequent(np.arange(0, 101, 1), 'recurrence')

# %% [markdown]
# Then we define the membership functions for each variable
# * Placeholder

# %%
#Age membership functions
age['young'] = fuzz.trapmf(age.universe, [10, 10, 25, 50])
age['middle_aged'] = fuzz.trimf(age.universe, [25, 50, 70])
age['elderly'] = fuzz.trapmf(age.universe, [50, 70, 100, 100])

#Tumor size membership function
tumor_size['small'] = fuzz.trapmf(tumor_size.universe, [0, 0, 15, 30])
tumor_size['medium'] = fuzz.trimf(tumor_size.universe, [15, 30, 55])
tumor_size['large'] = fuzz.trapmf(tumor_size.universe, [30, 55, 60, 60])

#inv nodes membership function
inv_nodes['few'] = fuzz.trapmf(inv_nodes.universe, [0, 0, 2, 10])
inv_nodes['moderate'] = fuzz.trimf(inv_nodes.universe, [2, 10, 15])
inv_nodes['many'] = fuzz.trapmf(inv_nodes.universe, [10, 15, 40, 40])

#deg_malig membership function
deg_malig['low'] = fuzz.trimf(deg_malig.universe, [1, 1, 4])
deg_malig['high'] = fuzz.trimf(deg_malig.universe, [1, 4, 4])

# Define membership functions for the output (recurrence)
recurrence['low'] = fuzz.trimf(recurrence.universe, [0, 0, 50])
recurrence['medium'] = fuzz.trimf(recurrence.universe, [0, 50, 100])
recurrence['high'] = fuzz.trimf(recurrence.universe, [50, 100, 100])

# %% [markdown]
# Then we define the fuzzy rules
# * Placeholder

# %%
# Define fuzzy rules based on the membership functions and reasoning

#age
rule1 = ctrl.Rule(age['young'] & inv_nodes['few'], recurrence['low'])
rule2 = ctrl.Rule(age['young'] & inv_nodes['moderate'], recurrence['medium'])
rule3 = ctrl.Rule(age['young'] & deg_malig['low'], recurrence['medium'])
rule4 = ctrl.Rule(age['young'] & deg_malig['high'], recurrence['high'])

rule5 = ctrl.Rule(age['middle_aged'] & inv_nodes['few'], recurrence['low'])
rule6 = ctrl.Rule(age['middle_aged'] & inv_nodes['moderate'], recurrence['medium'])
rule7 = ctrl.Rule(age['middle_aged'] & inv_nodes['many'], recurrence['medium'])
rule8 = ctrl.Rule(age['middle_aged'] & deg_malig['low'], recurrence['low'])
rule9 = ctrl.Rule(age['middle_aged'] & deg_malig['high'], recurrence['medium'])
rule10 = ctrl.Rule(age['middle_aged'] & tumor_size['small'], recurrence['low'])
rule11 = ctrl.Rule(age['middle_aged'] & tumor_size['medium'], recurrence['low'])
rule12 = ctrl.Rule(age['middle_aged'] & tumor_size['large'], recurrence['low'])

rule13 = ctrl.Rule(age['elderly'] & inv_nodes['few'], recurrence['low'])
rule14 = ctrl.Rule(age['elderly'] & inv_nodes['moderate'], recurrence['medium'])
rule15 = ctrl.Rule(age['elderly'] & inv_nodes['many'], recurrence['high'])
rule16 = ctrl.Rule(age['elderly'] & deg_malig['low'], recurrence['low'])
rule17 = ctrl.Rule(age['elderly'] & deg_malig['high'], recurrence['medium'])
rule18 = ctrl.Rule(age['elderly'] & tumor_size['small'], recurrence['low'])
rule19 = ctrl.Rule(age['elderly'] & tumor_size['medium'], recurrence['low'])
rule20 = ctrl.Rule(age['elderly'] & tumor_size['large'], recurrence['low'])

# # inv_nodes and degree_malignence
# rule29 = ctrl.Rule(inv_nodes['few'], recurrence['low'])
# rule30 = ctrl.Rule(inv_nodes['moderate'] & deg_malig['low'], recurrence['low'])
# rule31 = ctrl.Rule(inv_nodes['moderate'] & deg_malig['high'], recurrence['high'])
# rule32 = ctrl.Rule(inv_nodes['many'] & deg_malig['high'], recurrence['high'])

# # inv_nodes and tumor_size
# rule33 = ctrl.Rule(inv_nodes['few'], recurrence['low'])
# rule34 = ctrl.Rule(inv_nodes['moderate'] & tumor_size['large'], recurrence['high'])

# #degree_malignence and tumor_size
# rule35 = ctrl.Rule(deg_malig['high'] & tumor_size['large'] , recurrence['high'])
# rule36 = ctrl.Rule(deg_malig['low'] & tumor_size['small'] , recurrence['low'])
# rule37 = ctrl.Rule(deg_malig['low'] & tumor_size['medium'] , recurrence['low'])

recurrence_ctrl = ctrl.ControlSystem(rules=[rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9, rule10, rule11, rule12, rule13, rule14, rule15, rule16, rule17, rule18, rule19, rule20]) # Include all rules here

# %% [markdown]
# rules

# %% [markdown]
# Then we add the rules to the control system

# %% [markdown]
# recurrence_ctrl = ctrl.ControlSystem(rules)  # Include all rules here

# %% [markdown]
# Then we create simulution

# %%
# Create simulation
recurrence_sim = ctrl.ControlSystemSimulation(recurrence_ctrl)

# %%
# Define inputs
recurrence_sim.input['age'] = 64.5  # Replace with your input values
recurrence_sim.input['tumor_size'] = 22
recurrence_sim.input['inv_nodes'] = 1
recurrence_sim.input['deg_malig'] = 1

# Compute output
recurrence_sim.compute()

# Access output
print(f"Chance for recurrance is: {recurrence_sim.output['recurrence']}%")
# Out:
# Chance for recurrance is: 17.65522875816993%

# %%
count = 0 
correct = 0
for index, row in data_clean.iterrows():
    recurrence_sim.input['age'] = row["age"]
    recurrence_sim.input['tumor_size'] = row["tumor-size"]
    recurrence_sim.input['inv_nodes'] = row["inv-nodes"]
    recurrence_sim.input['deg_malig'] = row["deg-malig"]
    recurrence_sim.compute()
    crisp_output = 1 if recurrence_sim.output['recurrence'] >30 else 0
    correct = correct+1 if crisp_output == row["Class"] else correct
    count += 1
    string = "Correct" if crisp_output == row["Class"] else "Wrong"
    if (string == "Wrong"):
        print(f"Data number {count}: age={row['age']}, tumor_size={row['tumor-size']}, inv_nodes={row['inv-nodes']}, deg-malig={row['deg-malig']}")
        print(f"Percentage {recurrence_sim.output['recurrence']}%, Output {crisp_output}, Answer {row['Class']}, {string}")

print(f"Number of correct diagnoses {correct}") 
print(f"Number of wrong diagnoses {count-correct}") 
print(f"Total diagnoses {count}") 
print(f"Accuracy {correct/count*100}%")
# Out:
# Data number 1: age=34.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 50.00000000000009%, Output 1, Answer 0.0, Wrong
# Data number 2: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 3: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 4: age=64.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 5: age=44.5, tumor_size=2.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 6: age=64.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 7: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 9: age=44.5, tumor_size=52.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 10: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 11: age=44.5, tumor_size=2.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.822712195121994%, Output 1, Answer 0.0, Wrong
# Data number 12: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 14: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 15: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.822712195121994%, Output 1, Answer 0.0, Wrong
# Data number 17: age=44.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 18: age=54.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 19: age=64.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.09923212765291%, Output 1, Answer 0.0, Wrong
# Data number 21: age=54.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 22: age=64.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 23: age=34.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 45.59842873176206%, Output 1, Answer 0.0, Wrong
# Data number 24: age=54.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 25: age=54.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 26: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 28: age=64.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.09923212765291%, Output 1, Answer 0.0, Wrong
# Data number 29: age=44.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 30: age=64.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 31: age=54.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 32: age=54.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 33: age=54.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 36: age=34.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 45.59842873176206%, Output 1, Answer 0.0, Wrong
# Data number 37: age=54.5, tumor_size=2.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 39: age=44.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 40: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 42: age=64.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 44: age=44.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 47: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 49: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 50: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 51: age=54.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 52: age=34.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 45.59842873176206%, Output 1, Answer 0.0, Wrong
# Data number 54: age=74.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 40.853658536585414%, Output 1, Answer 0.0, Wrong
# Data number 58: age=54.5, tumor_size=7.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 61: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 62: age=44.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 64: age=24.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 43.34774520017861%, Output 1, Answer 0.0, Wrong
# Data number 65: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 66: age=44.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 67: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 68: age=54.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 69: age=54.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 70: age=64.5, tumor_size=52.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 72: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 73: age=64.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 74: age=54.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 75: age=34.5, tumor_size=7.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 45.59842873176206%, Output 1, Answer 0.0, Wrong
# Data number 77: age=54.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 78: age=34.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 42.97084059092965%, Output 1, Answer 0.0, Wrong
# Data number 79: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 80: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 81: age=54.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 83: age=64.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 84: age=54.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 85: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 86: age=54.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 87: age=64.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 89: age=54.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 90: age=44.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 91: age=34.5, tumor_size=2.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 45.59842873176206%, Output 1, Answer 0.0, Wrong
# Data number 92: age=54.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 93: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 94: age=64.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 96: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 97: age=64.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 98: age=64.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 99: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 100: age=34.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 45.59842873176206%, Output 1, Answer 0.0, Wrong
# Data number 101: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.822712195121994%, Output 1, Answer 0.0, Wrong
# Data number 102: age=54.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 103: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 104: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 105: age=44.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 106: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 107: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 108: age=34.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 45.59842873176206%, Output 1, Answer 0.0, Wrong
# Data number 109: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.822712195121994%, Output 1, Answer 0.0, Wrong
# Data number 113: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 114: age=44.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 115: age=44.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 116: age=54.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 117: age=34.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 42.97084059092965%, Output 1, Answer 0.0, Wrong
# Data number 118: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.822712195121994%, Output 1, Answer 0.0, Wrong
# Data number 119: age=34.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 42.97084059092965%, Output 1, Answer 0.0, Wrong
# Data number 122: age=54.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 123: age=54.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 126: age=74.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 36.66649482397975%, Output 1, Answer 0.0, Wrong
# Data number 127: age=34.5, tumor_size=32.0, inv_nodes=7.0, deg-malig=2.0
# Percentage 49.30637470905923%, Output 1, Answer 0.0, Wrong
# Data number 128: age=34.5, tumor_size=27.0, inv_nodes=7.0, deg-malig=2.0
# Percentage 49.30637470905923%, Output 1, Answer 0.0, Wrong
# Data number 129: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 130: age=44.5, tumor_size=37.0, inv_nodes=10.0, deg-malig=2.0
# Percentage 43.663969885948646%, Output 1, Answer 0.0, Wrong
# Data number 131: age=44.5, tumor_size=37.0, inv_nodes=10.0, deg-malig=2.0
# Percentage 43.663969885948646%, Output 1, Answer 0.0, Wrong
# Data number 132: age=44.5, tumor_size=42.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 43.05280246992362%, Output 1, Answer 0.0, Wrong
# Data number 133: age=44.5, tumor_size=32.0, inv_nodes=7.0, deg-malig=2.0
# Percentage 42.63176713615026%, Output 1, Answer 0.0, Wrong
# Data number 134: age=54.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 135: age=64.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 136: age=34.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 45.59842873176206%, Output 1, Answer 0.0, Wrong
# Data number 137: age=34.5, tumor_size=42.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 50.00000000000009%, Output 1, Answer 0.0, Wrong
# Data number 138: age=44.5, tumor_size=7.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 139: age=34.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 45.59842873176206%, Output 1, Answer 0.0, Wrong
# Data number 140: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 141: age=54.5, tumor_size=42.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 37.93265173569988%, Output 1, Answer 0.0, Wrong
# Data number 142: age=54.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 37.93265173569988%, Output 1, Answer 0.0, Wrong
# Data number 144: age=44.5, tumor_size=47.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 145: age=64.5, tumor_size=47.0, inv_nodes=7.0, deg-malig=3.0
# Percentage 42.525681363134936%, Output 1, Answer 0.0, Wrong
# Data number 146: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 147: age=64.5, tumor_size=52.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 148: age=54.5, tumor_size=32.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 149: age=34.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 50.00000000000009%, Output 1, Answer 0.0, Wrong
# Data number 150: age=54.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 151: age=54.5, tumor_size=27.0, inv_nodes=16.0, deg-malig=3.0
# Percentage 43.26852643134312%, Output 1, Answer 0.0, Wrong
# Data number 152: age=64.5, tumor_size=32.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 42.09923212765291%, Output 1, Answer 0.0, Wrong
# Data number 153: age=54.5, tumor_size=37.0, inv_nodes=16.0, deg-malig=3.0
# Percentage 43.70114506231417%, Output 1, Answer 0.0, Wrong
# Data number 154: age=64.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.09923212765291%, Output 1, Answer 0.0, Wrong
# Data number 155: age=34.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 50.00000000000009%, Output 1, Answer 0.0, Wrong
# Data number 156: age=64.5, tumor_size=42.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 157: age=54.5, tumor_size=27.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 41.697054971781405%, Output 1, Answer 0.0, Wrong
# Data number 160: age=44.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 161: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.822712195121994%, Output 1, Answer 0.0, Wrong
# Data number 162: age=44.5, tumor_size=32.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 163: age=64.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 164: age=64.5, tumor_size=27.0, inv_nodes=4.0, deg-malig=1.0
# Percentage 35.59121927961764%, Output 1, Answer 0.0, Wrong
# Data number 165: age=64.5, tumor_size=27.0, inv_nodes=4.0, deg-malig=1.0
# Percentage 35.59121927961764%, Output 1, Answer 0.0, Wrong
# Data number 166: age=44.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 39.64298573713389%, Output 1, Answer 0.0, Wrong
# Data number 167: age=44.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 39.64298573713389%, Output 1, Answer 0.0, Wrong
# Data number 168: age=44.5, tumor_size=42.0, inv_nodes=16.0, deg-malig=2.0
# Percentage 44.16680486719035%, Output 1, Answer 0.0, Wrong
# Data number 169: age=54.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 170: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 171: age=34.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 45.59842873176206%, Output 1, Answer 0.0, Wrong
# Data number 172: age=34.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 42.97084059092965%, Output 1, Answer 0.0, Wrong
# Data number 173: age=64.5, tumor_size=32.0, inv_nodes=7.0, deg-malig=2.0
# Percentage 41.8816224360844%, Output 1, Answer 0.0, Wrong
# Data number 174: age=54.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 37.93265173569988%, Output 1, Answer 0.0, Wrong
# Data number 175: age=54.5, tumor_size=27.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 176: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 177: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 178: age=64.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 179: age=54.5, tumor_size=27.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 180: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.822712195121994%, Output 1, Answer 0.0, Wrong
# Data number 181: age=44.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.822712195121994%, Output 1, Answer 0.0, Wrong
# Data number 182: age=44.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.822712195121994%, Output 1, Answer 0.0, Wrong
# Data number 183: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 33.823799942512274%, Output 1, Answer 0.0, Wrong
# Data number 184: age=54.5, tumor_size=32.0, inv_nodes=10.0, deg-malig=3.0
# Percentage 42.12481146304678%, Output 1, Answer 0.0, Wrong
# Data number 185: age=54.5, tumor_size=32.0, inv_nodes=10.0, deg-malig=3.0
# Percentage 42.12481146304678%, Output 1, Answer 0.0, Wrong
# Data number 186: age=44.5, tumor_size=22.0, inv_nodes=7.0, deg-malig=2.0
# Percentage 43.66777266151377%, Output 1, Answer 0.0, Wrong
# Data number 188: age=64.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 38.19137854848532%, Output 1, Answer 0.0, Wrong
# Data number 189: age=44.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 190: age=54.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 191: age=44.5, tumor_size=17.0, inv_nodes=13.0, deg-malig=3.0
# Percentage 42.822712195121994%, Output 1, Answer 0.0, Wrong
# Data number 192: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 193: age=54.5, tumor_size=32.0, inv_nodes=7.0, deg-malig=2.0
# Percentage 41.47100509272606%, Output 1, Answer 0.0, Wrong
# Data number 194: age=34.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 45.59842873176206%, Output 1, Answer 0.0, Wrong
# Data number 195: age=54.5, tumor_size=52.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 196: age=54.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 197: age=54.5, tumor_size=12.0, inv_nodes=4.0, deg-malig=1.0
# Percentage 35.08551228318299%, Output 1, Answer 0.0, Wrong
# Data number 198: age=44.5, tumor_size=12.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 39.35739130950054%, Output 1, Answer 0.0, Wrong
# Data number 199: age=54.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 37.6975981248459%, Output 1, Answer 0.0, Wrong
# Data number 201: age=64.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 42.09923212765291%, Output 1, Answer 0.0, Wrong
# Data number 214: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 17.355442176870742%, Output 0, Answer 1.0, Wrong
# Data number 230: age=64.5, tumor_size=47.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 17.65522875816993%, Output 0, Answer 1.0, Wrong
# Data number 264: age=54.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 17.355442176870742%, Output 0, Answer 1.0, Wrong
# Data number 265: age=54.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 17.355442176870742%, Output 0, Answer 1.0, Wrong
# Data number 284: age=64.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 17.65522875816993%, Output 0, Answer 1.0, Wrong
# Number of correct diagnoses 117
# Number of wrong diagnoses 169
# Total diagnoses 286
# Accuracy 40.909090909090914%
