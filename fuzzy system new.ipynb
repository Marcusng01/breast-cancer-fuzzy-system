# %% [markdown]
# # Breast Cancer Recurrance Prediction Fuzzy System Implementation
# First we install the scikit fuzzy library

# %%
# %pip install -U scikit-fuzzy
# Out:
# Requirement already satisfied: scikit-fuzzy in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (0.4.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.6.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from scikit-fuzzy) (1.23.5)
# Requirement already satisfied: scipy>=0.9.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from scikit-fuzzy) (1.10.1)
# Requirement already satisfied: networkx>=1.9.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from scikit-fuzzy) (3.1)
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Then we import pandas to manipulate dataframe, numpy to perform array calculations, scikit-fuzzy to implement th fuzzy system and control to determine the fuzzy variables

# %%
import pandas as pd
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %% [markdown]
# Then we load the dataset from the uciml repository

# %%
from ucimlrepo import fetch_ucirepo 
breast_cancer = fetch_ucirepo(id=14)
X = breast_cancer.data.features 
y = breast_cancer.data.targets 
data = X
data['Class'] = y  # Adding the target variable 'Class'
data
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    30-39   premeno      30-34       0-2        no          3   left
# 1    40-49   premeno      20-24       0-2        no          2  right
# 2    40-49   premeno      20-24       0-2        no          2   left
# 3    60-69      ge40      15-19       0-2        no          2  right
# 4    40-49   premeno        0-4       0-2        no          2  right
# ..     ...       ...        ...       ...       ...        ...    ...
# 281  30-39   premeno      30-34       0-2        no          2   left
# 282  30-39   premeno      20-24       0-2        no          3   left
# 283  60-69      ge40      20-24       0-2        no          1  right
# 284  40-49      ge40      30-34     5-Mar        no          3   left
# 285  50-59      ge40      30-34     5-Mar        no          3   left
#
#     breast-quad irradiat                 Class
# 0      left_low       no  no-recurrence-events
# 1      right_up       no  no-recurrence-events
# 2      left_low       no  no-recurrence-events
# 3       left_up       no  no-recurrence-events
# 4     right_low       no  no-recurrence-events
# ..          ...      ...                   ...
# 281     left_up       no     recurrence-events
# 282     left_up      yes     recurrence-events
# 283     left_up       no     recurrence-events
# 284    left_low       no     recurrence-events
# 285    left_low       no     recurrence-events
#
# [286 rows x 10 columns]

# %%
data_clean = data[["age","tumor-size","inv-nodes", "deg-malig", "Class"]]
from datetime import datetime

#Clean the ages by replacing range with average
for index, row in data_clean.iterrows():
    age_list = row["age"].split("-")
    age_average = (float(age_list[0]) + float(age_list[1])) / 2
    # Replace the value in the "age" column with the calculated average
    data_clean.at[index, "age"] = age_average

    tumor_size_list = row["tumor-size"].split("-")
    try:
        tumor_size_list[1] = datetime.strptime(tumor_size_list[1], '%b').month
    except:
        pass
    tumor_size_average = (float(tumor_size_list[0]) + float(tumor_size_list[1])) /2 
    data_clean.at[index, "tumor-size"] = tumor_size_average

    inv_nodes_list = row["inv-nodes"].split("-")
    try:
        inv_nodes_list[1] = datetime.strptime(inv_nodes_list[1], '%b').month
    except:
        pass
    inv_nodes_average = (float(inv_nodes_list[0]) + float(inv_nodes_list[1])) /2 
    data_clean.at[index, "inv-nodes"] = inv_nodes_average
    
    data_clean.at[index, "Class"] = 0 if row["Class"] == "no-recurrence-events" else 1

data_clean["age"] = data_clean["age"].astype(float)
data_clean["tumor-size"] = data_clean["tumor-size"].astype(float)
data_clean["inv-nodes"] = data_clean["inv-nodes"].astype(float)
data_clean["Class"] = data_clean["Class"].astype(float)
data_clean.to_csv('clean-breast-cancer.csv', index=False, header=True)
data_clean
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14804\3838638883.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean["age"] = data_clean["age"].astype(float)
# C:\Users\user\AppData\Local\Temp\ipykernel_14804\3838638883.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean["tumor-size"] = data_clean["tumor-size"].astype(float)
# C:\Users\user\AppData\Local\Temp\ipykernel_14804\3838638883.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean["inv-nodes"] = data_clean["inv-nodes"].astype(float)
# C:\Users\user\AppData\Local\Temp\ipykernel_14804\3838638883.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean["Class"] = data_clean["Class"].astype(float)
#       age  tumor-size  inv-nodes  deg-malig  Class
# 0    34.5        32.0        1.0          3    0.0
# 1    44.5        22.0        1.0          2    0.0
# 2    44.5        22.0        1.0          2    0.0
# 3    64.5        17.0        1.0          2    0.0
# 4    44.5         2.0        1.0          2    0.0
# ..    ...         ...        ...        ...    ...
# 281  34.5        32.0        1.0          2    1.0
# 282  34.5        22.0        1.0          3    1.0
# 283  64.5        22.0        1.0          1    1.0
# 284  44.5        32.0        4.0          3    1.0
# 285  54.5        32.0        4.0          3    1.0
#
# [286 rows x 5 columns]

# %% [markdown]
# Then we define the fuzzy variables:
# *  Placeholder

# %%
# Define fuzzy variables
age = ctrl.Antecedent(np.arange(10, 101, 1), 'age')
tumor_size = ctrl.Antecedent(np.arange(0, 61, 1), 'tumor_size')
inv_nodes = ctrl.Antecedent(np.arange(0, 41, 1), 'inv_nodes')
deg_malig = ctrl.Antecedent(np.arange(1, 4, 1), 'deg_malig')
recurrence = ctrl.Consequent(np.arange(0, 101, 1), 'recurrence')

# %% [markdown]
# Then we define the membership functions for each variable
# * Placeholder

# %%
#Age membership functions
age['young'] = fuzz.trapmf(age.universe, [10, 10, 25, 50])
age['middle_aged'] = fuzz.trimf(age.universe, [25, 50, 70])
age['elderly'] = fuzz.trapmf(age.universe, [50, 70, 100, 100])

#Tumor size membership function
tumor_size['small'] = fuzz.trapmf(tumor_size.universe, [0, 0, 15, 30])
tumor_size['medium'] = fuzz.trimf(tumor_size.universe, [15, 30, 40])
tumor_size['large'] = fuzz.trapmf(tumor_size.universe, [30, 40, 60, 60])

#inv nodes membership function
inv_nodes['few'] = fuzz.trapmf(inv_nodes.universe, [0, 0, 2, 10])
inv_nodes['moderate'] = fuzz.trimf(inv_nodes.universe, [2, 10, 15])
inv_nodes['many'] = fuzz.trapmf(inv_nodes.universe, [10, 15, 40, 40])

#deg_malig membership function
deg_malig['low'] = fuzz.trimf(deg_malig.universe, [1, 1, 4])
deg_malig['high'] = fuzz.trimf(deg_malig.universe, [2, 4, 4])

# Define membership functions for the output (recurrence)
recurrence['low'] = fuzz.trimf(recurrence.universe, [0, 0, 50])
recurrence['medium'] = fuzz.trimf(recurrence.universe, [0, 50, 100])
recurrence['high'] = fuzz.trimf(recurrence.universe, [50, 100, 100])

# %% [markdown]
# Then we define the fuzzy rules
# * Placeholder

# %%
# Define fuzzy rules based on the membership functions and reasoning

rule =[]
rule.append(ctrl.Rule(age['young'], recurrence['high']))
rule.append(ctrl.Rule(age['middle_aged'], recurrence['medium']))
rule.append(ctrl.Rule(age['elderly'], recurrence['low']))

rule.append(ctrl.Rule(inv_nodes['few'], recurrence['low']))
rule.append(ctrl.Rule(inv_nodes['moderate'], recurrence['medium']))
rule.append(ctrl.Rule(inv_nodes['many'], recurrence['high']))

rule.append(ctrl.Rule(deg_malig['low'], recurrence['low']))
rule.append(ctrl.Rule(deg_malig['high'], recurrence['high']))

rule.append(ctrl.Rule(tumor_size['small'], recurrence['low']))
rule.append(ctrl.Rule(tumor_size['medium'], recurrence['medium']))
rule.append(ctrl.Rule(tumor_size['large'], recurrence['high']))

# #age
# rule.append(ctrl.Rule(age['young'] & inv_nodes['few'], recurrence['low']))
# rule.append(ctrl.Rule(age['young'] & deg_malig['high'], recurrence['medium']))

# rule.append(ctrl.Rule(age['middle_aged'] & inv_nodes['few'], recurrence['low']))
# rule.append(ctrl.Rule(age['middle_aged'] & deg_malig['high'], recurrence['high']))
# rule.append(ctrl.Rule(age['middle_aged'] & tumor_size['small'], recurrence['low']))

# rule.append(ctrl.Rule(age['elderly'] & inv_nodes['few'], recurrence['low']))
# rule.append(ctrl.Rule(age['elderly'] & deg_malig['low'], recurrence['low']))
# rule.append(ctrl.Rule(age['elderly'] & deg_malig['high'], recurrence['high']))

# # # inv_nodes and degree_malignence
# rule.append(ctrl.Rule(inv_nodes['few'], recurrence['low']))
# rule.append(ctrl.Rule(inv_nodes['few'] & deg_malig['high'], recurrence['high']))
# rule.append(ctrl.Rule(inv_nodes['many'] & deg_malig['high'], recurrence['high']))

# # # inv_nodes and tumor_size
# rule.append(ctrl.Rule(inv_nodes['few'], recurrence['low']))
# rule.append(ctrl.Rule(inv_nodes['moderate'] & tumor_size['large'], recurrence['high']))

# # #degree_malignence and tumor_size
# rule.append(ctrl.Rule(deg_malig['high'] & tumor_size['large'] , recurrence['high']))
# rule.append(ctrl.Rule(tumor_size['small'] , recurrence['low']))
# rule.append(ctrl.Rule(deg_malig['low'] & tumor_size['medium'] , recurrence['low']))

recurrence_ctrl = ctrl.ControlSystem(rules=rule) # Include all rules here

# %% [markdown]
# rules

# %% [markdown]
# Then we add the rules to the control system

# %% [markdown]
# recurrence_ctrl = ctrl.ControlSystem(rules)  # Include all rules here

# %% [markdown]
# Then we create simulution

# %%
# Create simulation
recurrence_sim = ctrl.ControlSystemSimulation(recurrence_ctrl)

# %%
count = 0 
correct = 0
for index, row in data_clean.iterrows():
    recurrence_sim.input['age'] = row["age"]
    recurrence_sim.input['tumor_size'] = row["tumor-size"]
    recurrence_sim.input['inv_nodes'] = row["inv-nodes"]
    recurrence_sim.input['deg_malig'] = row["deg-malig"]
    recurrence_sim.compute()
    crisp_output = 1 if recurrence_sim.output['recurrence'] > 50 else 0
    correct = correct+1 if crisp_output == row["Class"] else correct
    count += 1
    string = "Correct" if crisp_output == row["Class"] else "Wrong"
    if (string == "Wrong"):
        print(f"Data number {count}: age={row['age']}, tumor_size={row['tumor-size']}, inv_nodes={row['inv-nodes']}, deg-malig={row['deg-malig']}")
        print(f"Percentage {recurrence_sim.output['recurrence']}%, Output {crisp_output}, Answer {row['Class']}, {string}")

print(f"Number of correct diagnoses {correct}") 
print(f"Number of wrong diagnoses {count-correct}") 
print(f"Total diagnoses {count}") 
print(f"Accuracy {correct/count*100}%")
# Out:
# Data number 21: age=54.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 50.000000000000014%, Output 1, Answer 0.0, Wrong
# Data number 24: age=54.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 50.000000000000014%, Output 1, Answer 0.0, Wrong
# Data number 31: age=54.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 50.000000000000014%, Output 1, Answer 0.0, Wrong
# Data number 45: age=54.5, tumor_size=52.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 50.000000000000014%, Output 1, Answer 0.0, Wrong
# Data number 70: age=64.5, tumor_size=52.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 50.00000000000004%, Output 1, Answer 0.0, Wrong
# Data number 123: age=54.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 50.000000000000014%, Output 1, Answer 0.0, Wrong
# Data number 130: age=44.5, tumor_size=37.0, inv_nodes=10.0, deg-malig=2.0
# Percentage 50.317365797715105%, Output 1, Answer 0.0, Wrong
# Data number 131: age=44.5, tumor_size=37.0, inv_nodes=10.0, deg-malig=2.0
# Percentage 50.317365797715105%, Output 1, Answer 0.0, Wrong
# Data number 132: age=44.5, tumor_size=42.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 51.00840755212913%, Output 1, Answer 0.0, Wrong
# Data number 134: age=54.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 50.000000000000014%, Output 1, Answer 0.0, Wrong
# Data number 137: age=34.5, tumor_size=42.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 51.28670140292565%, Output 1, Answer 0.0, Wrong
# Data number 141: age=54.5, tumor_size=42.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 51.00998971646834%, Output 1, Answer 0.0, Wrong
# Data number 145: age=64.5, tumor_size=47.0, inv_nodes=7.0, deg-malig=3.0
# Percentage 51.29946007724442%, Output 1, Answer 0.0, Wrong
# Data number 147: age=64.5, tumor_size=52.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 50.00000000000004%, Output 1, Answer 0.0, Wrong
# Data number 151: age=54.5, tumor_size=27.0, inv_nodes=16.0, deg-malig=3.0
# Percentage 56.27848012361285%, Output 1, Answer 0.0, Wrong
# Data number 153: age=54.5, tumor_size=37.0, inv_nodes=16.0, deg-malig=3.0
# Percentage 56.33163564568573%, Output 1, Answer 0.0, Wrong
# Data number 156: age=64.5, tumor_size=42.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 51.371335790767105%, Output 1, Answer 0.0, Wrong
# Data number 168: age=44.5, tumor_size=42.0, inv_nodes=16.0, deg-malig=2.0
# Percentage 51.76866561254192%, Output 1, Answer 0.0, Wrong
# Data number 184: age=54.5, tumor_size=32.0, inv_nodes=10.0, deg-malig=3.0
# Percentage 52.31891505260979%, Output 1, Answer 0.0, Wrong
# Data number 185: age=54.5, tumor_size=32.0, inv_nodes=10.0, deg-malig=3.0
# Percentage 52.31891505260979%, Output 1, Answer 0.0, Wrong
# Data number 195: age=54.5, tumor_size=52.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 50.000000000000014%, Output 1, Answer 0.0, Wrong
# Data number 202: age=54.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 41.314920965780814%, Output 0, Answer 1.0, Wrong
# Data number 203: age=44.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 49.99999999999998%, Output 0, Answer 1.0, Wrong
# Data number 204: age=54.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 48.5580774365821%, Output 0, Answer 1.0, Wrong
# Data number 205: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 41.39118457300279%, Output 0, Answer 1.0, Wrong
# Data number 206: age=34.5, tumor_size=2.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 47.05956600136795%, Output 0, Answer 1.0, Wrong
# Data number 207: age=54.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 208: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 41.39118457300279%, Output 0, Answer 1.0, Wrong
# Data number 209: age=54.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 210: age=44.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 48.56035831082038%, Output 0, Answer 1.0, Wrong
# Data number 211: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 42.41687061510849%, Output 0, Answer 1.0, Wrong
# Data number 212: age=54.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 41.314920965780814%, Output 0, Answer 1.0, Wrong
# Data number 213: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 214: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 41.39118457300279%, Output 0, Answer 1.0, Wrong
# Data number 216: age=44.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 42.41687061510849%, Output 0, Answer 1.0, Wrong
# Data number 217: age=54.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 41.314920965780814%, Output 0, Answer 1.0, Wrong
# Data number 218: age=44.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 42.41687061510849%, Output 0, Answer 1.0, Wrong
# Data number 219: age=64.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 220: age=34.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 47.05956600136795%, Output 0, Answer 1.0, Wrong
# Data number 221: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 222: age=34.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 47.72825094874383%, Output 0, Answer 1.0, Wrong
# Data number 223: age=64.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 224: age=64.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 45.23424632465077%, Output 0, Answer 1.0, Wrong
# Data number 225: age=34.5, tumor_size=27.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 48.73175211627537%, Output 0, Answer 1.0, Wrong
# Data number 226: age=44.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 47.08492556709252%, Output 0, Answer 1.0, Wrong
# Data number 228: age=54.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 232: age=44.5, tumor_size=32.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 43.46347867049063%, Output 0, Answer 1.0, Wrong
# Data number 233: age=34.5, tumor_size=32.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 48.73175211627537%, Output 0, Answer 1.0, Wrong
# Data number 234: age=74.5, tumor_size=17.0, inv_nodes=10.0, deg-malig=1.0
# Percentage 41.66666666666667%, Output 0, Answer 1.0, Wrong
# Data number 235: age=64.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 236: age=54.5, tumor_size=27.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 47.10370725471398%, Output 0, Answer 1.0, Wrong
# Data number 237: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 42.46848160751908%, Output 0, Answer 1.0, Wrong
# Data number 238: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 42.46848160751908%, Output 0, Answer 1.0, Wrong
# Data number 239: age=34.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 48.15808622885206%, Output 0, Answer 1.0, Wrong
# Data number 240: age=44.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 43.417514266181115%, Output 0, Answer 1.0, Wrong
# Data number 241: age=64.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 40.36497119331789%, Output 0, Answer 1.0, Wrong
# Data number 244: age=54.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 47.07990977928147%, Output 0, Answer 1.0, Wrong
# Data number 246: age=34.5, tumor_size=32.0, inv_nodes=10.0, deg-malig=2.0
# Percentage 49.50183982625561%, Output 0, Answer 1.0, Wrong
# Data number 247: age=34.5, tumor_size=17.0, inv_nodes=7.0, deg-malig=3.0
# Percentage 47.86585964472591%, Output 0, Answer 1.0, Wrong
# Data number 249: age=64.5, tumor_size=37.0, inv_nodes=7.0, deg-malig=3.0
# Percentage 49.75897592819254%, Output 0, Answer 1.0, Wrong
# Data number 250: age=34.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 48.45619531892624%, Output 0, Answer 1.0, Wrong
# Data number 251: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 252: age=44.5, tumor_size=52.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 49.99999999999998%, Output 0, Answer 1.0, Wrong
# Data number 253: age=34.5, tumor_size=42.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 50.0%, Output 0, Answer 1.0, Wrong
# Data number 255: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 257: age=44.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 42.46848160751908%, Output 0, Answer 1.0, Wrong
# Data number 258: age=44.5, tumor_size=22.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 43.417514266181115%, Output 0, Answer 1.0, Wrong
# Data number 259: age=54.5, tumor_size=32.0, inv_nodes=7.0, deg-malig=2.0
# Percentage 44.02764637863977%, Output 0, Answer 1.0, Wrong
# Data number 260: age=54.5, tumor_size=32.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 47.10370725471398%, Output 0, Answer 1.0, Wrong
# Data number 261: age=64.5, tumor_size=27.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 42.37804878048783%, Output 0, Answer 1.0, Wrong
# Data number 263: age=64.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 264: age=54.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 41.314920965780814%, Output 0, Answer 1.0, Wrong
# Data number 265: age=54.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 41.314920965780814%, Output 0, Answer 1.0, Wrong
# Data number 267: age=44.5, tumor_size=32.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 43.46347867049063%, Output 0, Answer 1.0, Wrong
# Data number 269: age=34.5, tumor_size=37.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 48.15808622885206%, Output 0, Answer 1.0, Wrong
# Data number 270: age=44.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 42.46848160751908%, Output 0, Answer 1.0, Wrong
# Data number 272: age=54.5, tumor_size=27.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.09862671660426%, Output 0, Answer 1.0, Wrong
# Data number 273: age=44.5, tumor_size=17.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 46.07392331272926%, Output 0, Answer 1.0, Wrong
# Data number 274: age=64.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 42.289972899729015%, Output 0, Answer 1.0, Wrong
# Data number 275: age=64.5, tumor_size=32.0, inv_nodes=4.0, deg-malig=2.0
# Percentage 43.28380257212375%, Output 0, Answer 1.0, Wrong
# Data number 278: age=64.5, tumor_size=12.0, inv_nodes=7.0, deg-malig=3.0
# Percentage 45.780590717299575%, Output 0, Answer 1.0, Wrong
# Data number 282: age=34.5, tumor_size=32.0, inv_nodes=1.0, deg-malig=2.0
# Percentage 47.72825094874383%, Output 0, Answer 1.0, Wrong
# Data number 283: age=34.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=3.0
# Percentage 47.24812336339835%, Output 0, Answer 1.0, Wrong
# Data number 284: age=64.5, tumor_size=22.0, inv_nodes=1.0, deg-malig=1.0
# Percentage 39.19482118318954%, Output 0, Answer 1.0, Wrong
# Data number 285: age=44.5, tumor_size=32.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 47.10370725471398%, Output 0, Answer 1.0, Wrong
# Data number 286: age=54.5, tumor_size=32.0, inv_nodes=4.0, deg-malig=3.0
# Percentage 47.10370725471398%, Output 0, Answer 1.0, Wrong
# Number of correct diagnoses 200
# Number of wrong diagnoses 86
# Total diagnoses 286
# Accuracy 69.93006993006993%
